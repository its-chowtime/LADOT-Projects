# %%
import pandas as pd
import numpy as np
import os

# %%
file = 'C:/Users/LADOT/Desktop/BigMart Project/Test_BigMart.txt'

# %%
bigmart_df = pd.read_csv(file)

# %%
bigmart_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
bigmart_df.dropna(axis=0, inplace=True)

# %%
bigmart_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 5              FDH56        9.800          Regular         0.063817
# 6              FDL48       19.350          Regular         0.082602
# 13             FDU11        4.785          Low Fat         0.092738
# 14             DRL59       16.750               LF         0.021206
# 15             FDM24        6.135          Regular         0.079451
# 17             DRC12       17.850          Low Fat         0.037981
# 20             FDA31        7.100          Low Fat         0.109920
# 21             NCJ31       19.200          Low Fat         0.182619
# 22             FDG52       13.650               LF         0.065631
# 24             FDS10       19.200          Low Fat         0.035179
# 26             NCF19       13.000          Low Fat         0.035102
# 27             NCE06        5.825          Low Fat         0.091485
# ...

# %%
bigmart_df.reset_index(inplace=True, drop=True)

# %%
bigmart_df.head(500)
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDW58       20.750          Low Fat         0.007565
# 1             FDH56        9.800          Regular         0.063817
# 2             FDL48       19.350          Regular         0.082602
# 3             FDU11        4.785          Low Fat         0.092738
# 4             DRL59       16.750               LF         0.021206
# 5             FDM24        6.135          Regular         0.079451
# 6             DRC12       17.850          Low Fat         0.037981
# 7             FDA31        7.100          Low Fat         0.109920
# 8             NCJ31       19.200          Low Fat         0.182619
# 9             FDG52       13.650               LF         0.065631
# 10            FDS10       19.200          Low Fat         0.035179
# 11            NCF19       13.000          Low Fat         0.035102
# 12            NCE06        5.825          Low Fat         0.091485
# ...
